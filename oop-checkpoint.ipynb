# %% [markdown]
# ## Object Oriented Programming

# %%
class Dog():

    species = 'mammal'

    def __init__(self, breed, name):

        #Attributes (we take in arguments and assign it using self.attribute_name)
        self.breed = breed
        self.name = name

    # METHOD
    def bark(self, number):
        print("WAWW, My name is {} and number is {}".format(self.name, number))

# %%
my_dog = Dog('Lab', 'Beast')

# %%
my_dog.name, my_dog.breed, my_dog.species
# Out:
# ('Beast', 'Lab', 'mammal')

# %%
my_dog.bark(26)
# Out:
# WAWW, My name is Beast and number is 26

# %%
class Circle():

    #Attribute for object Class
    pi = 3.14

    def __init__(self, radius):
        self.radius = radius

    #Method
    def get_circum(self):
        return self.radius * self.pi * 2

# %%
my_circle = Circle(20)

# %%
my_circle.get_circum()
# Out:
# 125.60000000000001

# %% [markdown]
# ### INHERITANCE

# %%
class Animal():

    def __init__(self):
        print("Animal Created")

    def who_am_i(self):
        print("An animal")

    def what_to_eat(self):
        print("Food")

# %%
myanimal.who_am_i()
# Out:
# An animal

# %%
class Dog(Animal):

    def __init__(self):
        Animal.__init__(self)
        print("Dog Created")

    # def who_am_i(self):
    #     print("A Dog")

# %%
mydog = Dog()
# Out:
# Animal Created
# Dog Created

# %%
mydog.what_to_eat()
# Out:
# Food

# %%
mydog.__init__()
# Out:
# Animal Created
# Dog Created

# %%
mydog.who_am_i()
# Out:
# An animal

# %% [markdown]
# ### POLYMORPHISM

# %%
class Dog():

    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name + " says WAWW"

# %%
class Tiger():

    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name + " says ROAR"

# %%
mydog = Dog("amigo")
mytiger = Tiger("beast")

# %%
print(mytiger.speak())
# Out:
# beast says ROAR

# %% [markdown]
# ### PRACTICE CODES
# * Fill in the line class methods to accept coordinates as a part of tuples and return the slope & distance of line

# %%
class Line():

    def __init__(self, coord1, coord2):
        self.coord1 = coord1
        self.coord2 = coord2

    def distance(self):
        x1, y1 = self.coord1
        x2, y2 = self.coord2
        return ((x2-x1)**2 + (y2-y1)**2)**0.5

    def slope(self):
        x1, y1 = self.coord1
        x2, y2 = self.coord2
        return (y2-y1)/(x2-x1)

# %%
# c1 = (4,2)
# c2 = (8,6)

# %%
myline = Line(coord1=(4,2),coord2=(8,6))

# %%
myline.distance()
# Out:
# 5.656854249492381

# %%
myline.slope()
# Out:
# 1.0

# %% [markdown]
# * Find the volume and surface area of class cylinder

# %%
class Cylinder():

    def __init__(self, height=1, radius=1):
        self.height = height
        self.radius = radius

    def volume(self):
        return 3.14 * (self.radius)**2 * self.height

    def surface_area(self):
        top = 3.14 * (self.radius**2)
        return (2 * top) + (2 * 3.14 * self.radius * self.height)

# %%
mycylin = Cylinder(2,3)

# %%
mycylin.volume()
# Out:
# 56.52

# %%
mycylin.surface_area()
# Out:
# 94.2
